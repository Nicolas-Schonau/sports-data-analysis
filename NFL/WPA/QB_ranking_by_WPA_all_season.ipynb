# %% [markdown]
# # Ranking the quarterbacks by their Win Probability Added

# %% [markdown]
# ## 1 : Import of the librairies and data

# %%
#Libraries import 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data import
YEAR = 2020
data = pd.read_csv(
    'https://github.com/guga31bb/nflfastR-data/blob/master/data/play_by_play_' \
    + str(YEAR) + '.csv.gz?raw=True',compression='gzip', low_memory=False
   )

# %% [markdown]
# ## 2. Cleaning and modification of the data

# %% [markdown]
# The table contains 2 columns defining the type of the pass:
# - pass_length : short or deep
# - pass_location : left, middle, or right
#
# We'll create a new column called "pass_type" by concatenating these two.
#
# Next, we'll calculate a new column called "wpa_pct" by multiplying the current wpa by 100. WPA is a probability ranging from 0 to 1 included. In order to make it easier to read, we'll transform it in a percentage.

# %%
data['pass_type'] = data['pass_length'] + '-' + data['pass_location']
data['wpa_pct'] = (100*data['wpa'])

# %% [markdown]
# Let's remove the data we do not want for our analysis, like kneel downs, field goals, penalties, etc, and assign this new dataframe to "df".
#
# Plus, we filter on the current week of the season.

# %%
#Indicate the most recent week, or the one you want to analyze in particular
week = 2

#Clean the data and only keep the pass plays. Note: test if the other conditions could be removed
df = data[
    (data.week<=week) &
    (data.play_type.isin(['pass'])) &
    (data.sack==0) &      
    (data.two_point_attempt==0) &
    (data['epa'].isna()==False) &
    (data['passer_player_name'].isna()==False)
    ]

# %%
#Correcting G.Minshew II that is present twice
df['passer_player_name'] = df['passer_player_name'].replace(['G.Minshew II'],'G.Minshew')
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Get the QBs + their teams with their general average WPA and the number of pass attempts
passer_wpa = df[['passer_player_name','posteam','pass_type','wpa_pct','play_id']].groupby(['passer_player_name','posteam']).agg(
    WPA=('wpa_pct', 'mean'),
    pass_attempts=('play_id','count')
)

#Filter on passer with at least 25 pass attempts
general_qb_wpa = passer_wpa[passer_wpa.pass_attempts>=25]

#Reset the index, otherwise passer_player_name is used as the index and that messes with the merge later on
general_qb_wpa.reset_index(inplace=True)

#Call it to make sure
general_qb_wpa
# Out:
#    passer_player_name posteam       WPA  pass_attempts
# 0           A.Rodgers      GB  0.702468             74
# 1          B.Mayfield     CLE  0.599799             62
# 2    B.Roethlisberger     PIT  0.966881             73
# 3            C.Newton      NE  0.813200             63
# 4             C.Wentz     PHI -0.479772             85
# 5             D.Brees      NO  0.136800             68
# 6              D.Carr      LV  1.464183             68
# 7           D.Haskins     WAS  0.055404             64
# 8             D.Jones     NYG -0.241962             79
# 9              D.Lock     DEN -0.776676             38
# 10         D.Prescott     DAL  0.703467             85
# 11           D.Watson     HOU -0.110568             67
# 12          G.Minshew     JAX  1.248106             65
# 13            J.Allen     BUF  1.568450             81
# 14           J.Burrow     CIN  0.722059             95
# 15          J.Driskel     DEN  0.463632             34
# 16        J.Garoppolo      SF  0.834414             49
# 17             J.Goff      LA  1.077840             58
# 18          J.Herbert     LAC  0.500409             32
# 19          K.Cousins     MIN -0.629949             50
# 20           K.Murray     ARI  0.169728             77
# 21          L.Jackson     BAL  1.187775             49
# 22             M.Ryan     ATL  0.460394             90
# 23         M.Stafford     DET -0.303690             74
# 24         M.Trubisky     CHI  0.501972             64
# 25          P.Mahomes      KC  1.038747             79
# 26           P.Rivers     IND  0.545672             71
# 27      R.Fitzpatrick     MIA  0.124569             76
# 28        R.Tannehill     TEN  1.387899             67
# 29           R.Wilson     SEA  1.120333             63
# 30          S.Darnold     NYJ  0.008924             65
# 31            T.Brady      TB -0.100400             71
# 32      T.Bridgewater     CAR  0.490087             76
# 33           T.Taylor     LAC  0.344798             30

# %%
#Make an Excel-like pivot table and calculate the average WPA per pass type
pass_type_wpa = pd.pivot_table(df, values='wpa_pct', index=['passer_player_name'],columns=['pass_type'], aggfunc=np.mean)

#Transform the table in a DataFrame
pass_type_wpa1 = pd.DataFrame(pass_type_wpa)

#Call it to make sure
pass_type_wpa1
# Out:
# pass_type           deep-left  deep-middle  deep-right  short-left  \
# passer_player_name
# A.Dalton                  NaN          NaN         NaN         NaN
# A.Rodgers           -2.441074     2.739894    1.815484   -0.469071
# B.Mayfield           2.814970    -0.260504    0.818284    1.488512
# B.Roethlisberger     1.378790     2.977087    1.578255    1.583525
# C.Jones                   NaN          NaN         NaN   -2.986316
# C.Newton             7.491416     1.907856    1.653803    0.127099
# C.Wentz             -1.040620    -1.506416    1.211711   -0.143003
# D.Brees             -1.008791     0.223183    1.692445    0.556758
# D.Carr              -0.992066     1.518148    5.612827    0.961904
# D.Haskins           -0.341048    -1.406776   -0.475864    0.240290
# D.Jones                   NaN     4.688547    2.264604   -1.514925
# D.Lock              -2.278127          NaN   -4.057506    1.438875
# D.Prescott           3.484088     4.832515   -0.050266    0.432718
# D.Watson             0.581352    -4.731249   -0.505282   -0.085875
# G.Minshew            1.992563     2.627327    2.515828   -0.378838
# J.Allen              5.860719    11.068140    6.197093    0.052023
# J.Burrow            -0.158065    -2.559251   -1.078342   -0.250420
# J.Driskel            3.272293          NaN    1.427525   -0.041500
# J.Garoppolo         -2.295935     5.610573   -2.121986    2.654201
# J.Goff               3.105672          NaN   -0.824233    1.731832
# J.Herbert           -0.553594    -0.337207   -2.447808   -0.637464
# K.Cousins           -0.867045     1.712374   -0.563086   -0.741826
# K.Murray            -0.318670    -0.208777   -0.803352    0.161719
# L.Jackson            3.289057     2.403194   -0.487030    1.308852
# M.Ryan               3.118518    -2.606223    0.985817    0.926720
# M.Stafford          -4.828919     8.926722   -0.932954   -0.354240
# M.Trubisky          -1.812519     0.910997    0.128447    1.189518
# N.Mullens                 NaN     0.229675   -0.726229    0.064741
# P.Mahomes           -3.465228          NaN    4.635088    0.568663
# P.Rivers             1.043826     0.024343    1.168652    1.179398
# R.Fitzpatrick        0.980618     3.641697    1.127306   -1.058402
# R.Gage              -4.154772          NaN         NaN         NaN
# R.Griffin                 NaN          NaN         NaN   -0.001168
# R.Tannehill          3.946108     4.651666   -3.266825    0.877882
# R.Wilson             3.493371          NaN    4.019781   -0.366164
# S.Darnold            0.159955    -1.210892   -1.296825    0.248713
# T.Brady             -2.027021     2.171135    0.533467   -0.173102
# T.Bridgewater        2.025932     0.504226    5.011648   -0.120330
# T.Hill                    NaN          NaN    0.188440         NaN
# T.Taylor            -1.325930          NaN    0.177103    0.394911
#
# pass_type           short-middle  short-right
# passer_player_name
# A.Dalton                     NaN    -0.522488
# A.Rodgers               4.083901     0.444752
# B.Mayfield              0.302217     0.162393
# B.Roethlisberger        0.716436    -0.287853
# C.Jones                      NaN          NaN
# C.Newton                1.898100    -0.542439
# C.Wentz                -0.252732    -0.673732
# D.Brees                -0.548783     0.365132
# D.Carr                  1.143411     1.788023
# D.Haskins               0.297040     0.238434
# D.Jones                 0.734106    -1.130279
# D.Lock                 -0.125863    -0.598704
# D.Prescott              0.218363     0.550489
# D.Watson                0.928040    -0.505491
# G.Minshew               1.688267     1.953793
# J.Allen                 0.027190     1.040857
# J.Burrow                2.129461     1.486606
# J.Driskel              -0.121834    -1.004124
# J.Garoppolo             3.738945    -3.035672
# J.Goff                  1.821220     0.112502
# J.Herbert               2.155014     0.822748
# K.Cousins              -0.447123    -1.219733
# K.Murray                1.827215     0.720895
# L.Jackson               1.350606     0.561843
# M.Ryan                 -0.189846    -0.342044
# M.Stafford             -0.586060     0.070251
# M.Trubisky              1.091311     0.534580
# N.Mullens               0.332437    -1.409887
# P.Mahomes               1.119701     1.532389
# P.Rivers                0.976682    -0.489918
# R.Fitzpatrick           0.872326    -0.247374
# R.Gage                       NaN          NaN
# R.Griffin                    NaN          NaN
# R.Tannehill             1.257096     1.633620
# R.Wilson                2.570421     1.417131
# S.Darnold               0.056458     0.050266
# T.Brady                 0.638608    -0.338705
# T.Bridgewater           0.237775    -0.488012
# T.Hill                       NaN          NaN
# T.Taylor                0.905103     1.383460

# %%
#Merge both df using passer_player_name as the unique key
total = pd.merge(general_qb_wpa,pass_type_wpa1, on='passer_player_name',how='left')
 
#Transform and work on the layout:
#sort by WPA (from best to worst), round to 2 decimals, remove the columns 'pass_attempts'
final = (
    total
    .sort_values(by=["WPA"],ascending=False)
    .round(2)
    .drop(columns='pass_attempts')
)
 
#Make the index start from 1 instead of 0 to have a ranking
final.index = np.arange(1,len(final)+1)
 
#Rename the columns to make it easier to read
final.rename(columns={"passer_player_name":"Quarterback", "posteam":"Team","WPA":"General"})
# Out:
#          Quarterback Team  General  deep-left  deep-middle  deep-right  \
# 1            J.Allen  BUF     1.57       5.86        11.07        6.20
# 2             D.Carr   LV     1.46      -0.99         1.52        5.61
# 3        R.Tannehill  TEN     1.39       3.95         4.65       -3.27
# 4          G.Minshew  JAX     1.25       1.99         2.63        2.52
# 5          L.Jackson  BAL     1.19       3.29         2.40       -0.49
# 6           R.Wilson  SEA     1.12       3.49          NaN        4.02
# 7             J.Goff   LA     1.08       3.11          NaN       -0.82
# 8          P.Mahomes   KC     1.04      -3.47          NaN        4.64
# 9   B.Roethlisberger  PIT     0.97       1.38         2.98        1.58
# 10       J.Garoppolo   SF     0.83      -2.30         5.61       -2.12
# 11          C.Newton   NE     0.81       7.49         1.91        1.65
# 12          J.Burrow  CIN     0.72      -0.16        -2.56       -1.08
# 13        D.Prescott  DAL     0.70       3.48         4.83       -0.05
# 14         A.Rodgers   GB     0.70      -2.44         2.74        1.82
# 15        B.Mayfield  CLE     0.60       2.81        -0.26        0.82
# 16          P.Rivers  IND     0.55       1.04         0.02        1.17
# 17        M.Trubisky  CHI     0.50      -1.81         0.91        0.13
# 18         J.Herbert  LAC     0.50      -0.55        -0.34       -2.45
# 19     T.Bridgewater  CAR     0.49       2.03         0.50        5.01
# 20         J.Driskel  DEN     0.46       3.27          NaN        1.43
# 21            M.Ryan  ATL     0.46       3.12        -2.61        0.99
# 22          T.Taylor  LAC     0.34      -1.33          NaN        0.18
# 23          K.Murray  ARI     0.17      -0.32        -0.21       -0.80
# 24           D.Brees   NO     0.14      -1.01         0.22        1.69
# 25     R.Fitzpatrick  MIA     0.12       0.98         3.64        1.13
# 26         D.Haskins  WAS     0.06      -0.34        -1.41       -0.48
# 27         S.Darnold  NYJ     0.01       0.16        -1.21       -1.30
# 28           T.Brady   TB    -0.10      -2.03         2.17        0.53
# 29          D.Watson  HOU    -0.11       0.58        -4.73       -0.51
# 30           D.Jones  NYG    -0.24        NaN         4.69        2.26
# 31        M.Stafford  DET    -0.30      -4.83         8.93       -0.93
# 32           C.Wentz  PHI    -0.48      -1.04        -1.51        1.21
# 33         K.Cousins  MIN    -0.63      -0.87         1.71       -0.56
# 34            D.Lock  DEN    -0.78      -2.28          NaN       -4.06
#
#     short-left  short-middle  short-right
# 1         0.05          0.03         1.04
# 2         0.96          1.14         1.79
# 3         0.88          1.26         1.63
# 4        -0.38          1.69         1.95
# 5         1.31          1.35         0.56
# 6        -0.37          2.57         1.42
# 7         1.73          1.82         0.11
# 8         0.57          1.12         1.53
# 9         1.58          0.72        -0.29
# 10        2.65          3.74        -3.04
# 11        0.13          1.90        -0.54
# 12       -0.25          2.13         1.49
# 13        0.43          0.22         0.55
# 14       -0.47          4.08         0.44
# 15        1.49          0.30         0.16
# 16        1.18          0.98        -0.49
# 17        1.19          1.09         0.53
# 18       -0.64          2.16         0.82
# 19       -0.12          0.24        -0.49
# 20       -0.04         -0.12        -1.00
# 21        0.93         -0.19        -0.34
# 22        0.39          0.91         1.38
# 23        0.16          1.83         0.72
# 24        0.56         -0.55         0.37
# 25       -1.06          0.87        -0.25
# 26        0.24          0.30         0.24
# 27        0.25          0.06         0.05
# 28       -0.17          0.64        -0.34
# 29       -0.09          0.93        -0.51
# 30       -1.51          0.73        -1.13
# 31       -0.35         -0.59         0.07
# 32       -0.14         -0.25        -0.67
# 33       -0.74         -0.45        -1.22
# 34        1.44         -0.13        -0.60

# %% [markdown]
# #Visualization

# %%
#Prepare a df with the needed data: QBs, team and general WPA
viz = final[['passer_player_name','posteam','WPA']]

#Call it to male sure
viz
# Out:
#    passer_player_name posteam   WPA
# 1             J.Allen     BUF  1.57
# 2              D.Carr      LV  1.46
# 3         R.Tannehill     TEN  1.39
# 4           G.Minshew     JAX  1.25
# 5           L.Jackson     BAL  1.19
# 6            R.Wilson     SEA  1.12
# 7              J.Goff      LA  1.08
# 8           P.Mahomes      KC  1.04
# 9    B.Roethlisberger     PIT  0.97
# 10        J.Garoppolo      SF  0.83
# 11           C.Newton      NE  0.81
# 12           J.Burrow     CIN  0.72
# 13         D.Prescott     DAL  0.70
# 14          A.Rodgers      GB  0.70
# 15         B.Mayfield     CLE  0.60
# 16           P.Rivers     IND  0.55
# 17         M.Trubisky     CHI  0.50
# 18          J.Herbert     LAC  0.50
# 19      T.Bridgewater     CAR  0.49
# 20          J.Driskel     DEN  0.46
# 21             M.Ryan     ATL  0.46
# 22           T.Taylor     LAC  0.34
# 23           K.Murray     ARI  0.17
# 24            D.Brees      NO  0.14
# 25      R.Fitzpatrick     MIA  0.12
# 26          D.Haskins     WAS  0.06
# 27          S.Darnold     NYJ  0.01
# 28            T.Brady      TB -0.10
# 29           D.Watson     HOU -0.11
# 30            D.Jones     NYG -0.24
# 31         M.Stafford     DET -0.30
# 32            C.Wentz     PHI -0.48
# 33          K.Cousins     MIN -0.63
# 34             D.Lock     DEN -0.78

# %%
#List of all colours and the related team id
COLORS = {'ARI':'#97233F','ATL':'#A71930','BAL':'#241773','BUF':'#00338D','CAR':'#0085CA','CHI':'#00143F',
          'CIN':'#FB4F14','CLE':'#FB4F14','DAL':'#B0B7BC','DEN':'#002244','DET':'#046EB4','GB':'#24423C',
          'HOU':'#C9243F','IND':'#003D79','JAX':'#136677','KC':'#CA2430','LA':'#002147','LAC':'#2072BA',
          'LV':'#C4C9CC','MIA':'#0091A0','MIN':'#4F2E84','NE':'#0A2342','NO':'#A08A58','NYG':'#192E6C',
          'NYJ':'#203731','PHI':'#014A53','PIT':'#FFC20E','SEA':'#7AC142','SF':'#C9243F','TB':'#D40909',
          'TEN':'#4095D1','WAS':'#FFC20F'}

# %%
#Make an Excel-like vlookup to create a new column with the correct color for each team
viz['color'] = viz['posteam'].map(COLORS)

#Call it to make sure
viz
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    passer_player_name posteam   WPA    color
# 1             J.Allen     BUF  1.57  #00338D
# 2              D.Carr      LV  1.46  #C4C9CC
# 3         R.Tannehill     TEN  1.39  #4095D1
# 4           G.Minshew     JAX  1.25  #136677
# 5           L.Jackson     BAL  1.19  #241773
# 6            R.Wilson     SEA  1.12  #7AC142
# 7              J.Goff      LA  1.08  #002147
# 8           P.Mahomes      KC  1.04  #CA2430
# 9    B.Roethlisberger     PIT  0.97  #FFC20E
# 10        J.Garoppolo      SF  0.83  #C9243F
# 11           C.Newton      NE  0.81  #0A2342
# 12           J.Burrow     CIN  0.72  #FB4F14
# 13         D.Prescott     DAL  0.70  #B0B7BC
# 14          A.Rodgers      GB  0.70  #24423C
# 15         B.Mayfield     CLE  0.60  #FB4F14
# 16           P.Rivers     IND  0.55  #003D79
# 17         M.Trubisky     CHI  0.50  #00143F
# 18          J.Herbert     LAC  0.50  #2072BA
# 19      T.Bridgewater     CAR  0.49  #0085CA
# 20          J.Driskel     DEN  0.46  #002244
# 21             M.Ryan     ATL  0.46  #A71930
# 22           T.Taylor     LAC  0.34  #2072BA
# 23           K.Murray     ARI  0.17  #97233F
# 24            D.Brees      NO  0.14  #A08A58
# 25      R.Fitzpatrick     MIA  0.12  #0091A0
# 26          D.Haskins     WAS  0.06  #FFC20F
# 27          S.Darnold     NYJ  0.01  #203731
# 28            T.Brady      TB -0.10  #D40909
# 29           D.Watson     HOU -0.11  #C9243F
# 30            D.Jones     NYG -0.24  #192E6C
# 31         M.Stafford     DET -0.30  #046EB4
# 32            C.Wentz     PHI -0.48  #014A53
# 33          K.Cousins     MIN -0.63  #4F2E84
# 34             D.Lock     DEN -0.78  #002244

# %%
#Create a figure that we'll be able to use several times if needed
fig,ax = plt.subplots(figsize=(20,7))

#Pass the colors into a list, so that we have them in the correct order
#Plus, if a team is missing, that won't create any problem later 
kleuren = viz['color'].tolist()

#Set your custom list of colors as the plot's color palette
#This only accepts a list, this is why we passed the colors into a list earlier
sns.set_palette(sns.color_palette(kleuren))

#Set the barplot and pass the data
ax = sns.barplot(data=viz, x='passer_player_name',y='WPA')

#Customize the layout : add a title, axis legends and general legend impact moyen de leurs passes sur la probabilité de gagner
ax.set_title(f"Average impact of QBs' passes on the Win Probability Added - 2020 season through week {week}")
ax.set_xlabel("Quarterbacks")
ax.set_ylabel("Win Probability Added")
plt.figtext(.78,.02,'@nicolasschonau - Data: nflfastR - min. 25 pass attempts',fontsize=8)

#Remove the top and right line
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Rotate the lables, otherwise they overlap and you can't read them
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

#Use this code to annotate the bars
for p in ax.patches:
             ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2.5, p.get_height()),
                 ha='center', va='center', fontsize=10, color='black', xytext=(0, 20),
                 textcoords='offset points')

#plt.tight_layout() automatically adjusts subplot parameters to give specified padding, so it's more beautiful
plt.tight_layout()
