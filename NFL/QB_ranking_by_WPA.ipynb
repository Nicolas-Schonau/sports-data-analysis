# %% [markdown]
# #Ranking the quarterbacks by their Win Probability Added

# %% [markdown]
# ## 1 : Import of the librairies and data

# %%
#Libraries import 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data import
YEAR = 2020
data = pd.read_csv(
    'https://github.com/guga31bb/nflfastR-data/blob/master/data/play_by_play_' \
    + str(YEAR) + '.csv.gz?raw=True',compression='gzip', low_memory=False
   )

# %% [markdown]
# ## 2. Cleaning and modification of the data

# %% [markdown]
# The table contains 2 columns defining the type of the pass:
# - pass_length : short or deep
# - pass_location : left, middle, or right
#
# We'll create a new column called "pass_type" by concatenating these two.
#
# Next, we'll calculate a new column called "wpa_pct" by multiplying the current wpa by 100. WPA is a probability ranging from 0 to 1 included. In order to make it easier to read, we'll transform it in a percentage.

# %%
data['pass_type'] = data['pass_length'] + '-' + data['pass_location']
data['wpa_pct'] = (100*data['wpa'])

# %% [markdown]
# Let's remove the data we do not want for our analysis, like kneel downs, field goals, penalties, etc, and assign this new dataframe to "df".
#
# Plus, we filter on the current week of the season.

# %%
#Filter on current week + only plays that are passes
df = data[
    (data.week==11) &
    (data.play_type.isin(['pass'])) &
    (data.sack==0) &      
    (data.two_point_attempt==0) &
    (data['epa'].isna()==False) &
    (data['passer_player_name'].isna()==False)
    ]

# %%
#Get the QBs + their teams with their general average WPA and the number of pass attempts
passer_wpa = df[['passer_player_name','posteam','pass_type','wpa_pct','play_id']].groupby(['passer_player_name','posteam']).agg(
    WPA=('wpa_pct', 'mean'),
    pass_attempts=('play_id','count')
)

#Filter on passer with at least 5 pass attempts
general_qb_wpa = passer_wpa[passer_wpa.pass_attempts>=5]

#Reset the index, otherwise passer_player_name is used as the index and that messes with the merge later on
general_qb_wpa.reset_index(inplace=True)

#Call it to make sure
general_qb_wpa
# Out:
#    passer_player_name posteam       WPA  pass_attempts
# 0            A.Dalton     DAL  0.804643             32
# 1           A.Rodgers      GB  0.382957             36
# 2             A.Smith     WAS -0.169001             25
# 3          B.Mayfield     CLE  0.966803             21
# 4    B.Roethlisberger     PIT  0.568805             46
# 5            C.Newton      NE  0.224253             40
# 6             C.Wentz     PHI -0.560668             35
# 7              D.Carr      LV  1.290959             31
# 8              D.Lock     DEN  0.139163             30
# 9            D.Watson     HOU  1.827264             37
# 10           J.Burrow     CIN  0.266506             34
# 11           J.Flacco     NYJ -0.974870             31
# 12             J.Goff      LA  0.972071             50
# 13          J.Herbert     LAC  0.461542             49
# 14            J.Luton     JAX -1.072105             37
# 15          K.Cousins     MIN  0.800006             30
# 16           K.Murray     ARI  0.477260             42
# 17          L.Jackson     BAL  0.320769             29
# 18             M.Ryan     ATL -0.132588             37
# 19         M.Stafford     DET -0.228091             33
# 20          P.Mahomes      KC  3.080305             45
# 21           P.Rivers     IND  0.627909             36
# 22           P.Walker     CAR  0.357204             34
# 23           R.Finley     CIN -0.546318             10
# 24      R.Fitzpatrick     MIA -0.648625             18
# 25        R.Tannehill     TEN  2.709633             31
# 26           R.Wilson     SEA  1.680176             28
# 27            T.Brady      TB -0.362022             48
# 28             T.Hill      NO  1.133221             23
# 29       T.Tagovailoa     MIA  0.251443             20

# %%
#Make an Excel-like pivot table and calculate the average WPA per pass type
pass_type_wpa = pd.pivot_table(df, values='wpa_pct', index=['passer_player_name'],columns=['pass_type'], aggfunc=np.mean)

#Transform the table in a DataFrame
pass_type_wpa1 = pd.DataFrame(pass_type_wpa)

#Call it to make sure
pass_type_wpa1
# Out:
# pass_type           deep-left  deep-middle  ...  short-middle  short-right
# passer_player_name                          ...
# A.Dalton                  NaN          NaN  ...     -6.127643    -0.391765
# A.Rodgers           -1.916128    13.545427  ...      6.150076     0.405612
# A.Smith             -2.345413     6.014997  ...     -1.066759    -0.105451
# B.Mayfield           2.437848     7.957792  ...      6.970361    -0.180981
# B.Roethlisberger     3.294823    -3.042072  ...     -0.877072     0.051309
# C.Newton             7.900499     5.957057  ...     -2.096413     0.311964
# C.Wentz              4.774860          NaN  ...     -1.650397    -0.381614
# D.Carr               2.308083          NaN  ...      4.285216    -0.051666
# D.Lock               3.422818    -1.448637  ...     -0.194226     0.153240
# D.Moore                   NaN          NaN  ...           NaN    -0.538331
# D.Watson             1.293941    -1.951328  ...      2.023289     0.978076
# J.Burrow             1.485638    -1.847648  ...     -0.113816    -0.095003
# J.Flacco            -1.545112          NaN  ...     -0.365904    -2.343245
# J.Goff               2.290317    -1.870281  ...      1.680859     0.934316
# J.Herbert            0.864398     1.774240  ...      2.417163    -0.306418
# J.Luton             -2.226083    -1.396158  ...      0.027758    -1.477695
# K.Cousins            8.152579          NaN  ...     -2.809995     0.773783
# K.Murray             3.892645          NaN  ...      1.655844     0.811576
# L.Jackson            1.659568     2.981858  ...      1.502705    -1.501570
# L.Woodside                NaN          NaN  ...           NaN     5.806604
# M.Ryan               0.264987     7.324726  ...      1.017268    -0.368721
# M.Stafford           0.951903          NaN  ...      0.506736    -0.384366
# P.Mahomes            0.093621    17.002656  ...      5.576116     0.926884
# P.Rivers             5.527221    -0.256970  ...      1.769644    -0.951800
# P.Walker             3.985786          NaN  ...      0.544746    -1.001190
# R.Finley            -1.493977          NaN  ...           NaN     0.024508
# R.Fitzpatrick       -1.983869   -15.947789  ...     -2.150183     0.964142
# R.Tannehill          0.576375    -1.727453  ...      4.212902     4.285554
# R.Wilson            -0.947633          NaN  ...      1.045579     1.612493
# T.Brady             -2.170962   -19.709849  ...      2.754514     1.300914
# T.Hill               4.826766     1.273251  ...      0.315148    -0.573169
# T.Kelce                   NaN          NaN  ...      5.306986          NaN
# T.Tagovailoa        -2.516688          NaN  ...     -0.695235     0.839658
#
# [33 rows x 6 columns]

# %%
#Merge both df using passer_player_name as the unique key
total = pd.merge(general_qb_wpa,pass_type_wpa1, on='passer_player_name',how='left')
 
#Transform and work on the layout:
#sort by WPA (from best to worst), round to 2 decimals, remove the columns 'pass_attempts'
final = (
    total
    .sort_values(by=["WPA"],ascending=False)
    .round(2)
    .drop(columns='pass_attempts')
)
 
#Make the index start from 1 instead of 0 to have a ranking
final.index = np.arange(1,len(final)+1)
 
#Rename the columns to make it easier to read
final.rename(columns={"passer_player_name":"Quarterback", "posteam":"Team","WPA":"General"})
# Out:
#          Quarterback Team  General  ...  short-left  short-middle  short-right
# 1          P.Mahomes   KC     3.08  ...        1.47          5.58         0.93
# 2        R.Tannehill  TEN     2.71  ...        0.25          4.21         4.29
# 3           D.Watson  HOU     1.83  ...        2.51          2.02         0.98
# 4           R.Wilson  SEA     1.68  ...        1.87          1.05         1.61
# 5             D.Carr   LV     1.29  ...        0.10          4.29        -0.05
# 6             T.Hill   NO     1.13  ...        1.83          0.32        -0.57
# 7             J.Goff   LA     0.97  ...        0.18          1.68         0.93
# 8         B.Mayfield  CLE     0.97  ...        0.40          6.97        -0.18
# 9           A.Dalton  DAL     0.80  ...        3.61         -6.13        -0.39
# 10         K.Cousins  MIN     0.80  ...        1.17         -2.81         0.77
# 11          P.Rivers  IND     0.63  ...        0.85          1.77        -0.95
# 12  B.Roethlisberger  PIT     0.57  ...        0.80         -0.88         0.05
# 13          K.Murray  ARI     0.48  ...        0.27          1.66         0.81
# 14         J.Herbert  LAC     0.46  ...        0.73          2.42        -0.31
# 15         A.Rodgers   GB     0.38  ...       -5.60          6.15         0.41
# 16          P.Walker  CAR     0.36  ...        0.17          0.54        -1.00
# 17         L.Jackson  BAL     0.32  ...        0.55          1.50        -1.50
# 18          J.Burrow  CIN     0.27  ...        3.12         -0.11        -0.10
# 19      T.Tagovailoa  MIA     0.25  ...        0.81         -0.70         0.84
# 20          C.Newton   NE     0.22  ...        0.74         -2.10         0.31
# 21            D.Lock  DEN     0.14  ...        0.05         -0.19         0.15
# 22            M.Ryan  ATL    -0.13  ...       -1.29          1.02        -0.37
# 23           A.Smith  WAS    -0.17  ...       -0.24         -1.07        -0.11
# 24        M.Stafford  DET    -0.23  ...       -0.76          0.51        -0.38
# 25           T.Brady   TB    -0.36  ...       -0.37          2.75         1.30
# 26          R.Finley  CIN    -0.55  ...       -2.77           NaN         0.02
# 27           C.Wentz  PHI    -0.56  ...        0.20         -1.65        -0.38
# 28     R.Fitzpatrick  MIA    -0.65  ...        0.72         -2.15         0.96
# 29          J.Flacco  NYJ    -0.97  ...       -0.23         -0.37        -2.34
# 30           J.Luton  JAX    -1.07  ...       -0.49          0.03        -1.48
#
# [30 rows x 9 columns]

# %% [markdown]
# #Visualization

# %%
#Prepare a df with the needed data: QBs, team and general WPA
viz = final[['passer_player_name','posteam','WPA']]

#Call it to male sure
viz
# Out:
#    passer_player_name posteam   WPA
# 1           P.Mahomes      KC  3.08
# 2         R.Tannehill     TEN  2.71
# 3            D.Watson     HOU  1.83
# 4            R.Wilson     SEA  1.68
# 5              D.Carr      LV  1.29
# 6              T.Hill      NO  1.13
# 7              J.Goff      LA  0.97
# 8          B.Mayfield     CLE  0.97
# 9            A.Dalton     DAL  0.80
# 10          K.Cousins     MIN  0.80
# 11           P.Rivers     IND  0.63
# 12   B.Roethlisberger     PIT  0.57
# 13           K.Murray     ARI  0.48
# 14          J.Herbert     LAC  0.46
# 15          A.Rodgers      GB  0.38
# 16           P.Walker     CAR  0.36
# 17          L.Jackson     BAL  0.32
# 18           J.Burrow     CIN  0.27
# 19       T.Tagovailoa     MIA  0.25
# 20           C.Newton      NE  0.22
# 21             D.Lock     DEN  0.14
# 22             M.Ryan     ATL -0.13
# 23            A.Smith     WAS -0.17
# 24         M.Stafford     DET -0.23
# 25            T.Brady      TB -0.36
# 26           R.Finley     CIN -0.55
# 27            C.Wentz     PHI -0.56
# 28      R.Fitzpatrick     MIA -0.65
# 29           J.Flacco     NYJ -0.97
# 30            J.Luton     JAX -1.07

# %%
#List of all colours and the related team id
COLORS = {'ARI':'#97233F','ATL':'#A71930','BAL':'#241773','BUF':'#00338D','CAR':'#0085CA','CHI':'#00143F',
          'CIN':'#FB4F14','CLE':'#FB4F14','DAL':'#B0B7BC','DEN':'#002244','DET':'#046EB4','GB':'#24423C',
          'HOU':'#C9243F','IND':'#003D79','JAX':'#136677','KC':'#CA2430','LA':'#002147','LAC':'#2072BA',
          'LV':'#C4C9CC','MIA':'#0091A0','MIN':'#4F2E84','NE':'#0A2342','NO':'#A08A58','NYG':'#192E6C',
          'NYJ':'#203731','PHI':'#014A53','PIT':'#FFC20E','SEA':'#7AC142','SF':'#C9243F','TB':'#D40909',
          'TEN':'#4095D1','WAS':'#FFC20F'}

# %%
#Make an Excel-like vlookup to create a new column with the correct color for each team
viz['color'] = viz['posteam'].map(COLORS)

#Call it to make sure
viz
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    passer_player_name posteam   WPA    color
# 1           P.Mahomes      KC  3.08  #CA2430
# 2         R.Tannehill     TEN  2.71  #4095D1
# 3            D.Watson     HOU  1.83  #C9243F
# 4            R.Wilson     SEA  1.68  #7AC142
# 5              D.Carr      LV  1.29  #C4C9CC
# 6              T.Hill      NO  1.13  #A08A58
# 7              J.Goff      LA  0.97  #002147
# 8          B.Mayfield     CLE  0.97  #FB4F14
# 9            A.Dalton     DAL  0.80  #B0B7BC
# 10          K.Cousins     MIN  0.80  #4F2E84
# 11           P.Rivers     IND  0.63  #003D79
# 12   B.Roethlisberger     PIT  0.57  #FFC20E
# 13           K.Murray     ARI  0.48  #97233F
# 14          J.Herbert     LAC  0.46  #2072BA
# 15          A.Rodgers      GB  0.38  #24423C
# 16           P.Walker     CAR  0.36  #0085CA
# 17          L.Jackson     BAL  0.32  #241773
# 18           J.Burrow     CIN  0.27  #FB4F14
# 19       T.Tagovailoa     MIA  0.25  #0091A0
# 20           C.Newton      NE  0.22  #0A2342
# 21             D.Lock     DEN  0.14  #002244
# 22             M.Ryan     ATL -0.13  #A71930
# 23            A.Smith     WAS -0.17  #FFC20F
# 24         M.Stafford     DET -0.23  #046EB4
# 25            T.Brady      TB -0.36  #D40909
# 26           R.Finley     CIN -0.55  #FB4F14
# 27            C.Wentz     PHI -0.56  #014A53
# 28      R.Fitzpatrick     MIA -0.65  #0091A0
# 29           J.Flacco     NYJ -0.97  #203731
# 30            J.Luton     JAX -1.07  #136677

# %%
#Create a figure that we'll be able to use several times if needed
fig,ax = plt.subplots(figsize=(15,7))

#Pass the colors into a list, so that we have them in the correct order
#Plus, if a team is missing, that won't create any problem later 
kleuren = viz['color'].tolist()

#Set your custom list of colors as the plot's color palette
#This only accepts a list, this is why we passed the colors into a list earlier
sns.set_palette(sns.color_palette(kleuren))

#Set the barplot and pass the data
ax = sns.barplot(data=viz, x='passer_player_name',y='WPA')

#Customize the layout : add a title, axis legends and general legend impact moyen de leurs passes sur la probabilité de gagner
ax.set_title("Average impact of QBs' passes on the Win Probability Added - week 11")
ax.set_xlabel("Quarterbacks")
ax.set_ylabel("Win Probability Added")
plt.figtext(.78,.02,'@nicolasschonau - Data: nflfastR - min. 5 pass attempts',fontsize=8)

#Remove the top and right line
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Rotate the lables, otherwise they overlap and you can't read them
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

#Use this code to annotate the bars
for p in ax.patches:
             ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, 20),
                 textcoords='offset points')

#plt.tight_layout() automatically adjusts subplot parameters to give specified padding, so it's more beautiful
plt.tight_layout()
